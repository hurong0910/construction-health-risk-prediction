# %% [markdown]
# # Demo: Clinically-Guided Risk Prediction Pipeline
#
# This notebook shows how to run the full pipeline:
# 1. Load and sort data
# 2. Clinical scoring + AHP weighting
# 3. Next-step target derivation
# 4. Train/evaluate multiple models
# 5. Export Table 11 and Figure 6

# %%
import os, sys
import pandas as pd
from pathlib import Path

repo_root = Path('..').resolve()
sys.path.append(str(repo_root))
print('Repo root:', repo_root)

# %%
from src.utils import load_config
from src.modeling import train_and_eval_all

cfg = load_config(str(repo_root / 'config.yaml'))
res = train_and_eval_all(cfg)
res

# %% [markdown]
# The following files are saved:
# - `results/tables/table11_model_comparison.csv`
# - `results/figures/figure6_prc_by_class.png`
